# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq

# %%
flipkart_url="https://www.flipkart.com/search?q="+"mobile"+"samsung"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=mobilesamsung'

# %%
uClient = uReq(flipkart_url)

# %%
uClient

# %%
flipkartPage = uClient.read()

# %%
flipkartPage
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app_modules.chunk.94b5e7.css"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.dd97f3.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/a
# ...

# %%
flipkart_html = bs(flipkartPage, "html.parser")

# %%
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
bigboxes = flipkart_html.findAll("div",{"class":"_2kHMtA"})

# %%
bigboxes
# Out:
# [<div class="_2kHMtA"><a class="_1fQZEK" href="/samsung-galaxy-f22-denim-blue-128-gb/p/itm30c755943bea0?pid=MOBG43UGRSMJXTMH&amp;lid=LSTMOBG43UGRSMJXTMH3SYSZ3&amp;marketplace=FLIPKART&amp;q=mobilesamsung&amp;store=tyy%2F4io&amp;srno=s_1_1&amp;otracker=search&amp;fm=organic&amp;iid=92ffc3bb-53ca-4b78-a728-01f59aae639e.MOBG43UGRSMJXTMH.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=66tz2x3esw0000001639071941032&amp;qH=9017d1ba9475ffb8" rel="noopener noreferrer" target="_blank"><div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="SAMSUNG Galaxy F22 (Denim Blue, 128 GB)" class="_396cs4 _3exPp9" src="https://rukminim1.flixcart.com/image/312/312/kqqykcw0/mobile/j/5/7/galaxy-f22-sm-e225flbdins-samsung-original-imag4z99fp4qdfby.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label 
# ...

# %%
bigboxes2 = flipkart_html.findAll("div",{"class":"MIXNux"})

# %%
bigboxes2
# Out:
# [<div class="MIXNux"><div class="_2QcLo-"><div><div class="CXW8mj" style="height:200px;width:200px"><img alt="SAMSUNG Galaxy F22 (Denim Blue, 128 GB)" class="_396cs4 _3exPp9" src="https://rukminim1.flixcart.com/image/312/312/kqqykcw0/mobile/j/5/7/galaxy-f22-sm-e225flbdins-samsung-original-imag4z99fp4qdfby.jpeg?q=70"/></div></div></div><div class="_3wLduG"><div class="_3PzNI-"><span class="f3A4_V"><label class="_2iDkf8"><input class="_30VH1S" readonly="" type="checkbox"/><div class="_24_Dny"></div></label></span><label class="_6Up2sF"><span>Add to Compare</span></label></div></div><div class="_2hVSre _3nq8ih"><div class="_36FSn5"><svg class="_1l0elc" height="16" viewbox="0 0 20 16" width="16" xmlns="http://www.w3.org/2000/svg"><path class="eX72wL" d="M8.695 16.682C4.06 12.382 1 9.536 1 6.065 1 3.219 3.178 1 5.95 1c1.566 0 3.069.746 4.05 1.915C10.981 1.745 12.484 1 14.05 1 16.822 1 19 3.22 19 6.065c0 3.471-3.06 6.316-7.695 10.617L10 17.897l-1.305-1.215z" fill="#2874F0" fill-rule="eveno
# ...

# %%
bigbox = flipkart_html.findAll("div",{"class":"_1AtVbE col-12-12"})

# %%
bigbox
# Out:
# [<div class="_1AtVbE col-12-12"><div class="_1KOcBL"><section class="JWMl0H _2hbLCH"><div class="_2ssEMF"><div class="_3V8rao"><span>Filters</span></div></div></section><div class="_2q_g77"><section class="_2aDURW"><div class="_2lfNTw"><span>CATEGORIES</span></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="_3zK8He" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_2qvBBJ _2Mji8F" href="/mobiles-accessories/pr?sid=tyy&amp;q=mobilesamsung&amp;otracker=categorytree" title="Mobiles &amp; Accessories">Mobiles &amp; Accessories</a></div></div><div><div class="TB_InB"><span><svg class="_2Iqv73" height="10" viewbox="0 0 16 27" width="10" xmlns="http://www.w3.org/2000/svg"><path class="" d="M16 23.207L6.11 13.161 16 3.093 12.955 0 0 13.161l12.955 13.161z" fill="#fff"></path></svg></span><a class="_1jJQdf _2Mji8F" href="/mobiles/pr?si
# ...

# %%
len(bigbox)
# Out:
# 30

# %%
box = bigbox[25]

# %%
url_mobile="https://www.flipkart.com"+box.div.div.div.a['href']

# %%
url_mobile
# Out:
# 'https://www.flipkart.com/samsung-galaxy-a22-5g-gray-128-gb/p/itmec5c318d07f46?pid=MOBG54F2RKZH9FNZ&lid=LSTMOBG54F2RKZH9FNZT5GT0F&marketplace=FLIPKART&q=mobilesamsung&store=tyy%2F4io&srno=s_1_24&otracker=search&fm=organic&iid=92ffc3bb-53ca-4b78-a728-01f59aae639e.MOBG54F2RKZH9FNZ.SEARCH&ppt=None&ppn=None&ssid=66tz2x3esw0000001639071941032&qH=9017d1ba9475ffb8'

# %%
uClient_mobile = uReq(url_mobile)

# %%
uClient_mobile

# %%
prodRes = requests.get(url_mobile)

# %%
prodRes
# Out:
# <Response [200]>

# %%
prod_html = bs(prodRes.text,"html.parser")

# %%
prod_html
# Out:
# <!DOCTYPE html>
# ...

# %%
review= prod_html.findAll("div",{"class":"_16PBlm"})

# %%
len(review)
# Out:
# 11

# %%
commentbox = review[0]

# %%
commentbox.div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})
# Out:
# [<p class="_2sc7ZR _2V5EHH">khushbu purbey</p>]

# %%
rating = commentbox.div.div.div.p.text

# %%
rating
# Out:
# 'Best in the market!'

# %%
commentbox.div.div.find_all('div',{'class':''})
# Out:
# [<div><div class="">It's a good phone if you are looking a 5g underbudget  and don't wanna buy Chinese brand. Definitely go for this then . Camera is also good but front camera is good when light is good and night camara mode is good  specially front and other things are fair enough.</div><span class="_1H-bmy"><span>READ MORE</span></span></div>,
#  <div class="">It's a good phone if you are looking a 5g underbudget  and don't wanna buy Chinese brand. Definitely go for this then . Camera is also good but front camera is good when light is good and night camara mode is good  specially front and other things are fair enough.</div>,
#  <div></div>]

# %%
comtag =commentbox.div.div.find_all('div',{'class':''})

# %%
comtag[0].div.text
# Out:
# "It's a good phone if you are looking a 5g underbudget  and don't wanna buy Chinese brand. Definitely go for this then . Camera is also good but front camera is good when light is good and night camara mode is good  specially front and other things are fair enough."
